# %%
import csv
import sqlite3
import os
import pandas as pd

pd.set_option('display.max_columns', None)

# %%
def preprocess_text_column(col:pd.Series) -> pd.Series:
    """
    Arregla texto de una columna que contiene caracteres especiales
    y espacios.
    """

    ## Remove special chars
    series = col.replace(r'[^\w\sáéíóúÁÉÍÓÚñÑ]', '', regex=True)

    ## Remove double white spaces
    series = series.replace(r'\s+', ' ', regex=True)
    series = series.str.strip()
    series = series.str.lower()

    ## Capitalize what columns cointains. "valle del cauca" -> "Valle Del Cauca"
    series = series.apply(lambda t: ' '.join([l.capitalize() for l in t.split(' ')]))
    return series


def preprocess_read_reps_data(data_path:str) -> pd.DataFrame:
    """
    Función para leer información descargada de REPS. En las bases de datos de "Sedes"
    y "Servicios" tienen la particularidad de que al hacer la lectura con pandas se 
    corren los encabezados una columna. 
    """
    
    ## Read dataframe from data_path
    df = pd.read_csv(data_path, sep=';', encoding='ISO-8859-1', on_bad_lines='skip', dtype=str)
    
    ## Alocate first colum from index
    df = df.reset_index(names='wildcard')

    ## Clean columns names and assign correct order
    cols = [c.upper().strip() for c in df.columns]

    ## Move WILCARD column to last position
    cols = cols[1:] + ['WILDCARD']
    df.columns = cols
    
    ## Preprocess data to handle it as text to facilitate joins
    for col in df:
        df[col] = df[col].str.strip()
        df[col] = df[col].str.upper()

    return df


def crear_conexion(db_file):
    """Crea una conexión a la base de datos SQLite especificada por db_file.
    :param db_file: Ruta del archivo de la base de datos.
    :return: Objeto de conexión o None.
    """
    conn = None
    try:
        conn = sqlite3.connect(db_file)
        return conn
    except sqlite3.Error as e:
        print(f"Error al conectar a la base de datos: {e}")
    return conn

# Crear la carpeta 'data/processed' si no existe
ruta_db = 'data/processed/reps_data.db'
os.makedirs(os.path.dirname(ruta_db), exist_ok=True)

# %% [markdown]
# ### Preprocesamiento municipios

# %%
## Leer el dataframe
data_path = 'data/raw/Municipios.xlsx'
df_municipios = pd.read_excel(data_path)
df_municipios.head(2)
# Out:
#    DP Departamento  MPIO       Municipio  Superficie   PopTot  Rural  \
# 0   5   Ant%ioqUia  5001      Mede&l'lín  350.666623  2634570    1.6
# 1   5   Ant%ioquia  5002   Abej!&orr*al   497.566212    21622   56.7
#
#                  Region
# 0  Región Eje Cafetero
# 1  Región Eje Cafetero

# %%
## Preprocesar las columnas de departamento y municipio
for col in ['Departamento', 'Municipio']:
    df_municipios[col] = preprocess_text_column(df_municipios[col])

df_municipios.head(2)
# Out:
#    DP Departamento   MPIO  Municipio  Superficie   PopTot  Rural  \
# 0  05    Antioquia  05001   Medellín  350.666623  2634570    1.6
# 1  05    Antioquia  05002  Abejorral  497.566212    21622   56.7
#
#                  Region
# 0  Región Eje Cafetero
# 1  Región Eje Cafetero

# %%
## Fix MPIO codes
def fix_divipola_codes(series:pd.Series, fix_len:int=4) -> pd.Series:
    series = series.astype(str)
    series = series.apply(lambda t: f'0{t}' if len(t) == fix_len else t)
    return series

df_municipios['MPIO'] = fix_divipola_codes(df_municipios['MPIO'], fix_len=4)
df_municipios['DP'] = fix_divipola_codes(df_municipios['DP'], fix_len=1)

df_municipios.head(2)
# Out:
#    DP Departamento   MPIO  Municipio  Superficie   PopTot  Rural  \
# 0  05    Antioquia  05001   Medellín  350.666623  2634570    1.6
# 1  05    Antioquia  05002  Abejorral  497.566212    21622   56.7
#
#                  Region
# 0  Región Eje Cafetero
# 1  Región Eje Cafetero

# %%
## Enviar datos limpios a la db en data/processed

conn = crear_conexion(ruta_db)
df_municipios.to_sql(name='reps_municipios', con=conn, if_exists='replace', index=False)
# Out:
# 1118

# %% [markdown]
# ### Servicios preprocessing

# %%
## Leer la tabla de servicios
data_path = 'data/raw/Servicios.zip'
df_servicios = preprocess_read_reps_data(data_path)
df_servicios.head(2)
# Out:
#   DEPA_NOMBRE MUNI_NOMBRE HABI_CODIGO_HABILITACION CODIGO_HABILITACION  \
# 0   ANTIOQUIA    MEDELLÍN               0500100003          0500100003
# 1   ANTIOQUIA    MEDELLÍN               0500100008          0500100008
#
#   NUMERO_SEDE                  SEDE_NOMBRE  \
# 0          01  BERNARDO  AGUDELO JARAMILLO
# 1          01    ANA CARMENZA POSADA ISAZA
#
#                                            DIRECCION TELEFONO  \
# 0                         CL 19A N° 44- 25 CONS 2301  3665349
# 1  CL  2 SUR # 46 - 55 CS 253 FASE II CLINICA LAS...  2687270
#
#                              EMAIL  NITS_NIT DV CLASE_PERSONA NAJU_CODIGO  \
# 0        CONSULTORIO2301@GMAIL.COM  71578430  0       NATURAL           1
# 1  CORREOCLINICALASVEGAS@GMAIL.COM  32530725  0       NATURAL           1
#
#   NAJU_NOMBRE CLPR_CODIGO                CLPR_NOMBRE ESE NIVEL CARACTER  \
# 0     PRIVADA           2  PROFESIONAL INDEPENDIENTE                NaN
# 1     PRIVADA           2  PROFESIONAL INDEPENDIENTE                NaN
#
#   HABILITADO GRSE_CODIGO       GRSE_NOMBRE SERV_CODIGO       SERV_NOMBRE  \
# 0         SI           3  CONSULTA EXTERNA         320  GINECOBSTETRICIA
# 1         SI           3  CONSULTA EXTERNA         328  MEDICINA GENERAL
#
#   AMBULATORIO HOSPITALARIO UNIDAD_MOVIL DOMICILIARIO OTRAS_EXTRAMURAL  \
# 0          SI           NO           NO           NO               NO
# 1          SI           NO           NO           NO               NO
#
#   CENTRO_REFERENCIA INSTITUCION_REMISORA COMPLEJIDAD_BAJA COMPLEJIDAD_MEDIA  \
# 0                NO                   NO               NO                SI
# 1                NO                   NO               SI                NO
#
#   COMPLEJIDAD_ALTA FECHA_APERTURA FECHA_CIERRE NUMERO_DISTINTIVO  \
# 0               NO       20110727          NaN       DHSS0107311
# 1               NO       20121121          NaN       DHSS0019899
#
#   NUMERO_SEDE_PRINCIPAL OBSERVACIONES_SERV_RES3100_2019  \
# 0                    01                             NaN
# 1                    01                             NaN
#
#                         FECHA_CORTE_REPS                       NOMBRE  \
# 0  FECHA CORTE REPS: MAY 13 2025 12:58PM  BERNARDO  AGUDELO JARAMILLO
# 1  FECHA CORTE REPS: MAY 13 2025 12:58PM    ANA CARMENZA POSADA ISAZA
#
#   HORARIO_LUNES HORARIO_MARTES HORARIO_MIERCOLES HORARIO_JUEVES  \
# 0   08:00A17:00            NaN               NaN            NaN
# 1   08:00A12:00    08:00A18:00       08:00A12:00    08:00A18:00
#
#   HORARIO_VIERNES HORARIO_SABADO HORARIO_DOMINGO MODALIDAD_INTRAMURAL  \
# 0     08:00A17:00            NaN             NaN                   SI
# 1     08:00A12:00            NaN             NaN                   SI
#
#   MODALIDAD_EXTRAMURAL MODALIDAD_UNIDAD_MOVIL MODALIDAD_DOMICILIARIO  \
# 0                   NO                     NO                     NO
# 1                   NO                     NO                     NO
#
#   MODALIDAD_JORNADA_SALUD MODALIDAD_TELEMEDICINA  \
# 0                      NO                     NO
# 1                      NO                     NO
#
#   MODALIDAD_PRESTADOR_REFERENCIA  \
# 0                             NO
# 1                             NO
#
#   MODALIDAD_PRESTADOR_REFERENCIA_TELEMEDICINA_INTERACTIVA  \
# 0                                                 NO
# 1                                                 NO
#
#   MODALIDAD_PRESTADOR_REFERENCIA_TELEMEDICINA_NO_INTERACTIVA  \
# 0                                                 NO
# 1                                                 NO
#
#   MODALIDAD_PRESTADOR_REFERENCIA_TELE_EXPERTICIA  \
# 0                                             NO
# 1                                             NO
#
#   MODALIDAD_PRESTADOR_REFERENCIA_TELE_MONITOREO MODALIDAD_PRESTADOR_REMISOR  \
# 0                                            NO                          NO
# 1                                            NO                          NO
#
#   MODALIDAD_PRESTADOR_REMISOR_TELE_EXPERTICIA  \
# 0                                          NO
# 1                                          NO
#
#   MODALIDAD_PRESTADOR_REMISOR_TELE_MONITOREO COMPLEJIDADES  \
# 0                                         NO       MEDIANA
# 1                                         NO          BAJA
#
#   ESPECIFICIDAD_ONCOLOGICO ESPECIFICIDAD_TRASPLANTE_OSTEOMUSCULAR  \
# 0                       NO                                     NO
# 1                       NO                                     NO
#
#   ESPECIFICIDAD_TRASPLANTE_PIEL ESPECIFICIDAD_TRASPLANTE_CARDIOVASCULAR  \
# 0                            NO                                      NO
# 1                            NO                                      NO
#
#   ESPECIFICIDAD_TRASPLANTE_TEJIDO_OCULAR  \
# 0                                     NO
# 1                                     NO
#
#   ESPECIFICIDAD_ATENCION_PACIENTE_QUEMADO ESPECIFICIDAD_SALUD_MENTAL  \
# 0                                      NO                         NO
# 1                                      NO                         NO
#
#   ESPECIFICIDAD_SPA ESPECIFICIDAD_OTRAS_PATOLOGIAS  \
# 0                NO                             NO
# 1                NO                             NO
#
#   ESPECIFICIDAD_TRASPLANTE_CELULAS_PROGENITORAS_HEMATOPOYETICAS  \
# 0                                                 NO
# 1                                                 NO
#
#   ESPECIFICIDAD_PROCEDIMIENTOS_QUIRURGICOS_AMBULATORIOS  \
# 0                                                 NO
# 1                                                 NO
#
#   ESPECIFICIDAD_ORGANO_RINON ESPECIFICIDAD_ORGANO_HIGADO  \
# 0                         NO                          NO
# 1                         NO                          NO
#
#   ESPECIFICIDAD_ORGANO_PANCREAS ESPECIFICIDAD_ORGANO_INTESTINO  \
# 0                            NO                             NO
# 1                            NO                             NO
#
#   ESPECIFICIDAD_ORGANO_MULTIVISCERAL ESPECIFICIDAD_ORGANO_CORAZON  \
# 0                                 NO                           NO
# 1                                 NO                           NO
#
#   ESPECIFICIDAD_ORGANO_PULMON ESPECIFICIDAD_SUSTANCIAS_PSICOACTIVAS  \
# 0                          NO                                    NO
# 1                          NO                                    NO
#
#   ESPECIFICIDAD_TRASPLANTE_RENAL    VERSION_NORMA EMAIL_ADICIONAL  \
# 0                             NO  RESOLUCION_3100             NaN
# 1                             NO  RESOLUCION_3100             NaN
#
#   TELEFONO_ADICIONAL GERENTE MUNICIPIO PDET MUNICIPIO ZOMAC MUNICIPIO PNIS  \
# 0                NaN     NaN             NO              NO             NO
# 1                NaN     NaN             NO              NO             NO
#
#   MUNICIPIO PNSR ANTES 2023 MUNICIPIO PNSR 2023 MUNICIPIO PNSR 2024 WILDCARD
# 0                        NO                  NO                  NO      NaN
# 1                        NO                  NO                  NO      NaN

# %%
## Enviar datos limpios a la db en data/processed
ruta_db = 'data/processed/reps_data.db'
conn = crear_conexion(ruta_db)

df_servicios.to_sql(name='reps_servicios', con=conn, if_exists='replace', index=False)
# Out:
# 226641

# %% [markdown]
# ### Sedes preprocessing (paso a paso)

# %%
## Read table as pandas dataframe
data_path = 'data/raw/Sedes.zip'
df_sedes = pd.read_csv(data_path, sep=';', encoding='ISO-8859-1', on_bad_lines='skip', dtype=str)
df_sedes.head(2)
# Out:
#          departamento   municipio                       codigo_prestador  \
# Amazonas   EL ENCANTO  9100100019  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA
# Amazonas  LA CHORRERA  9100100019  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA
#
#          nombre_prestador codigo_habilitacion  \
# Amazonas       9126300019                  11
# Amazonas       9140500019                  14
#
#                                                 numero_sede  \
# Amazonas  CENTRO DE SALUD SAN RAFAEL - E.S.E HOSPITAL SA...
# Amazonas  CENTRO DE SALUD DE LA CHORRERA- E.S.E HOSPITAL...
#
#                                nombre gerente                     tipo_zona  \
# Amazonas  DENNIS AMPARO VASQUEZ ARIAS   RURAL     CORREGIMIENTO DEL ENCANTO
# Amazonas  DENNIS AMPARO VASQUEZ ARIAS   RURAL  CORREGIMIENTO DE LA CHORRERA
#
#          direccion    barrio  cepo_codigo centro_poblado telefono  \
# Amazonas       NaN  91263000   EL ENCANTO     3203016139      NaN
# Amazonas       NaN  91405000  LA CHORRERA     3203016132      NaN
#
#                                                         fax     email  \
# Amazonas  sanrafael@esehospitalsanrafael-leticia-amazona...  20110331
# Amazonas  chorrera@esehospitalsanrafael-leticia-amazonas...  20110323
#
#          fecha_apertura fecha_cierre nits_nit        dv clase_persona  \
# Amazonas            NaN    838000096        7  JURIDICO             4
# Amazonas            NaN    838000096        7  JURIDICO             4
#
#          naju_codigo naturaleza  \
# Amazonas     Pública          1
# Amazonas     Pública          1
#
#                                                 clpr_codigo clase_prestador  \
# Amazonas  Instituciones Prestadoras de Servicios de Salu...              SI
# Amazonas  Instituciones Prestadoras de Servicios de Salu...              SI
#
#          ese          nivel caracter sede_principal habilitado  \
# Amazonas   2  DEPARTAMENTAL       NO             SI         01
# Amazonas   2  DEPARTAMENTAL       NO             SI         01
#
#          numero_sede_principal horario_lunes horario_martes horario_miercoles  \
# Amazonas               07 a 18       07 a 18        07 a 18           07 a 18
# Amazonas               00 a 24       00 a 24        00 a 24           00 a 24
#
#          horario_jueves horario_viernes horario_sabado  \
# Amazonas        07 a 18         00 a 24        00 a 24
# Amazonas        00 a 24         00 a 24        00 a 24
#
#                                 horario_domingo fecha_corte_REPS  \
# Amazonas  Fecha corte REPS: May 13 2025 12:52PM              NaN
# Amazonas  Fecha corte REPS: May 13 2025 12:52PM              NaN
#
#          telefono_adicional email_adicional Municipio PDET Municipio ZOMAC  \
# Amazonas                NaN              NO             NO              NO
# Amazonas                NaN              NO             NO              NO
#
#          Municipio PNIS Municipio PNSR antes 2023 Municipio PNSR 2023  \
# Amazonas             SI                        SI                  SI
# Amazonas             SI                        SI                  SI
#
#          Municipio PNSR 2024
# Amazonas                 NaN
# Amazonas                 NaN

# %%
## Alocate first colum from index
df_sedes = df_sedes.reset_index(names='wildcard')
df_sedes.head(2)
# Out:
#    wildcard departamento   municipio                       codigo_prestador  \
# 0  Amazonas   EL ENCANTO  9100100019  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA
# 1  Amazonas  LA CHORRERA  9100100019  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA
#
#   nombre_prestador codigo_habilitacion  \
# 0       9126300019                  11
# 1       9140500019                  14
#
#                                          numero_sede  \
# 0  CENTRO DE SALUD SAN RAFAEL - E.S.E HOSPITAL SA...
# 1  CENTRO DE SALUD DE LA CHORRERA- E.S.E HOSPITAL...
#
#                         nombre gerente                     tipo_zona  \
# 0  DENNIS AMPARO VASQUEZ ARIAS   RURAL     CORREGIMIENTO DEL ENCANTO
# 1  DENNIS AMPARO VASQUEZ ARIAS   RURAL  CORREGIMIENTO DE LA CHORRERA
#
#   direccion    barrio  cepo_codigo centro_poblado telefono  \
# 0       NaN  91263000   EL ENCANTO     3203016139      NaN
# 1       NaN  91405000  LA CHORRERA     3203016132      NaN
#
#                                                  fax     email fecha_apertura  \
# 0  sanrafael@esehospitalsanrafael-leticia-amazona...  20110331            NaN
# 1  chorrera@esehospitalsanrafael-leticia-amazonas...  20110323            NaN
#
#   fecha_cierre nits_nit        dv clase_persona naju_codigo naturaleza  \
# 0    838000096        7  JURIDICO             4     Pública          1
# 1    838000096        7  JURIDICO             4     Pública          1
#
#                                          clpr_codigo clase_prestador ese  \
# 0  Instituciones Prestadoras de Servicios de Salu...              SI   2
# 1  Instituciones Prestadoras de Servicios de Salu...              SI   2
#
#            nivel caracter sede_principal habilitado numero_sede_principal  \
# 0  DEPARTAMENTAL       NO             SI         01               07 a 18
# 1  DEPARTAMENTAL       NO             SI         01               00 a 24
#
#   horario_lunes horario_martes horario_miercoles horario_jueves  \
# 0       07 a 18        07 a 18           07 a 18        07 a 18
# 1       00 a 24        00 a 24           00 a 24        00 a 24
#
#   horario_viernes horario_sabado                        horario_domingo  \
# 0         00 a 24        00 a 24  Fecha corte REPS: May 13 2025 12:52PM
# 1         00 a 24        00 a 24  Fecha corte REPS: May 13 2025 12:52PM
#
#   fecha_corte_REPS telefono_adicional email_adicional Municipio PDET  \
# 0              NaN                NaN              NO             NO
# 1              NaN                NaN              NO             NO
#
#   Municipio ZOMAC Municipio PNIS Municipio PNSR antes 2023  \
# 0              NO             SI                        SI
# 1              NO             SI                        SI
#
#   Municipio PNSR 2023 Municipio PNSR 2024
# 0                  SI                 NaN
# 1                  SI                 NaN

# %%
## Clean columns names and assign correct order
cols = [c.upper().strip() for c in df_sedes.columns]

## Move WILCARD column to last position
cols = cols[1:] + ['WILDCARD']

df_sedes.columns = cols
df_sedes.head(2)
# Out:
#   DEPARTAMENTO    MUNICIPIO CODIGO_PRESTADOR  \
# 0     Amazonas   EL ENCANTO       9100100019
# 1     Amazonas  LA CHORRERA       9100100019
#
#                         NOMBRE_PRESTADOR CODIGO_HABILITACION NUMERO_SEDE  \
# 0  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA          9126300019          11
# 1  E.S.E. HOSPITAL SAN RAFAEL DE LETICIA          9140500019          14
#
#                                               NOMBRE  \
# 0  CENTRO DE SALUD SAN RAFAEL - E.S.E HOSPITAL SA...
# 1  CENTRO DE SALUD DE LA CHORRERA- E.S.E HOSPITAL...
#
#                        GERENTE TIPO_ZONA                     DIRECCION BARRIO  \
# 0  DENNIS AMPARO VASQUEZ ARIAS     RURAL     CORREGIMIENTO DEL ENCANTO    NaN
# 1  DENNIS AMPARO VASQUEZ ARIAS     RURAL  CORREGIMIENTO DE LA CHORRERA    NaN
#
#   CEPO_CODIGO CENTRO_POBLADO    TELEFONO  FAX  \
# 0    91263000     EL ENCANTO  3203016139  NaN
# 1    91405000    LA CHORRERA  3203016132  NaN
#
#                                                EMAIL FECHA_APERTURA  \
# 0  sanrafael@esehospitalsanrafael-leticia-amazona...       20110331
# 1  chorrera@esehospitalsanrafael-leticia-amazonas...       20110323
#
#   FECHA_CIERRE   NITS_NIT DV CLASE_PERSONA NAJU_CODIGO NATURALEZA CLPR_CODIGO  \
# 0          NaN  838000096  7      JURIDICO           4    Pública           1
# 1          NaN  838000096  7      JURIDICO           4    Pública           1
#
#                                      CLASE_PRESTADOR ESE NIVEL       CARACTER  \
# 0  Instituciones Prestadoras de Servicios de Salu...  SI     2  DEPARTAMENTAL
# 1  Instituciones Prestadoras de Servicios de Salu...  SI     2  DEPARTAMENTAL
#
#   SEDE_PRINCIPAL HABILITADO NUMERO_SEDE_PRINCIPAL HORARIO_LUNES  \
# 0             NO         SI                    01       07 a 18
# 1             NO         SI                    01       00 a 24
#
#   HORARIO_MARTES HORARIO_MIERCOLES HORARIO_JUEVES HORARIO_VIERNES  \
# 0        07 a 18           07 a 18        07 a 18         07 a 18
# 1        00 a 24           00 a 24        00 a 24         00 a 24
#
#   HORARIO_SABADO HORARIO_DOMINGO                       FECHA_CORTE_REPS  \
# 0        00 a 24         00 a 24  Fecha corte REPS: May 13 2025 12:52PM
# 1        00 a 24         00 a 24  Fecha corte REPS: May 13 2025 12:52PM
#
#   TELEFONO_ADICIONAL EMAIL_ADICIONAL MUNICIPIO PDET MUNICIPIO ZOMAC  \
# 0                NaN             NaN             NO              NO
# 1                NaN             NaN             NO              NO
#
#   MUNICIPIO PNIS MUNICIPIO PNSR ANTES 2023 MUNICIPIO PNSR 2023  \
# 0             NO                        SI                  SI
# 1             NO                        SI                  SI
#
#   MUNICIPIO PNSR 2024 WILDCARD
# 0                  SI      NaN
# 1                  SI      NaN

# %%
## Preprocess data to handle it as text to facilitate joins
for col in df_sedes:
    df_sedes[col] = df_sedes[col].str.strip()
    df_sedes[col] = df_sedes[col].str.upper()

df_sedes.tail(2)
# Out:
#       DEPARTAMENTO      MUNICIPIO CODIGO_PRESTADOR  \
# 74500      VICHADA  SANTA ROSALÍA       9900100006
# 74501      VICHADA  SANTA ROSALÍA       9962400150
#
#                                      NOMBRE_PRESTADOR CODIGO_HABILITACION  \
# 74500  E.S.E. HOSPITAL DEPARTAMENTAL SAN JUAN DE DIOS          9962400006
# 74501                         JOSE OMAR OSPINA JAIMES          9962400150
#
#       NUMERO_SEDE                       NOMBRE                        GERENTE  \
# 74500          09  HOSPITAL SEDE SANTA ROSALIA  ALVARO ALBERTO CARDOSO CASTRO
# 74501          01      JOSE OMAR OSPINA JAIMES                            NaN
#
#       TIPO_ZONA       DIRECCION     BARRIO CEPO_CODIGO CENTRO_POBLADO  \
# 74500    URBANA       EL CENTRO  EL CENTRO    99624000  SANTA ROSALÍA
# 74501    URBANA  CRA 8 # 5 - 75     CENTRO                        NaN
#
#          TELEFONO  FAX                              EMAIL FECHA_APERTURA  \
# 74500  3102349354  NaN  CALIDAD@ESESANJUANDEDIOSPC.GOV.CO       20161205
# 74501  3214665867  NaN     OSPINAJAIMESJOSEOMAR@GMAIL.COM       20211011
#
#       FECHA_CIERRE    NITS_NIT   DV CLASE_PERSONA NAJU_CODIGO NATURALEZA  \
# 74500          NaN   842000004    4      JURIDICO           4    PÚBLICA
# 74501          NaN  1121844096  NaN       NATURAL           1    PRIVADA
#
#       CLPR_CODIGO                                    CLASE_PRESTADOR ESE  \
# 74500           1  INSTITUCIONES PRESTADORAS DE SERVICIOS DE SALU...  SI
# 74501           2                          PROFESIONAL INDEPENDIENTE
#
#       NIVEL       CARACTER SEDE_PRINCIPAL HABILITADO NUMERO_SEDE_PRINCIPAL  \
# 74500     2  DEPARTAMENTAL             NO         SI                    01
# 74501                  NaN             SI         SI                    01
#
#       HORARIO_LUNES HORARIO_MARTES HORARIO_MIERCOLES HORARIO_JUEVES  \
# 74500       00 A 24        00 A 24           00 A 24        00 A 24
# 74501           NaN            NaN               NaN            NaN
#
#       HORARIO_VIERNES HORARIO_SABADO HORARIO_DOMINGO  \
# 74500         00 A 24        00 A 24         00 A 24
# 74501             NaN            NaN             NaN
#
#                             FECHA_CORTE_REPS TELEFONO_ADICIONAL  \
# 74500  FECHA CORTE REPS: MAY 13 2025 12:52PM                NaN
# 74501  FECHA CORTE REPS: MAY 13 2025 12:52PM         3202901466
#
#                 EMAIL_ADICIONAL MUNICIPIO PDET MUNICIPIO ZOMAC MUNICIPIO PNIS  \
# 74500                       NaN             NO              NO             NO
# 74501  JOSEOSPINA21@HOTMAIL.COM             NO              NO             NO
#
#       MUNICIPIO PNSR ANTES 2023 MUNICIPIO PNSR 2023 MUNICIPIO PNSR 2024  \
# 74500                        SI                  SI                  SI
# 74501                        SI                  SI                  SI
#
#       WILDCARD
# 74500      NaN
# 74501      NaN

# %%
## Load table to database
ruta_db = 'data/processed/reps_data.db'
conn = crear_conexion(ruta_db)

df_sedes.to_sql(name='reps_sedes', con=conn, if_exists='replace', index=False)
# Out:
# 74502

# %% [markdown]
# ### Generación de query para extraer información de la base de datos
#
# Para este ejercicio específico, usando las columnas 'ESPECIFICIDAD_ONCOLOGICO' y 'ESPECIFICIDAD_TRASPLANTE_RENAL' se quiere generar un dato de la cantidad de sedes que tienen la marcación 'SI' en estas columnas y generar una cantidad por cada 100.000 habitantes para regiones y una por cada 10.000 habitantes para municipios.

# %%
# Generate the sql query
query = (
    f"""
    -- Crear cte para procesar tablas y facilitar la lectura del código
    
    -- traer la tabla de servicios oncologicos y la cantidad de sedes por 
    -- municipios.
    WITH servicios AS (
        SELECT CODIGO_HABILITACION
            , COMPLEJIDADES
            , SERV_NOMBRE
            , ESPECIFICIDAD_ONCOLOGICO
            , ESPECIFICIDAD_TRASPLANTE_RENAL 
            , SUBSTRING(CODIGO_HABILITACION, 1, 5) AS COD_MUNICIPIO
            , CODIGO_HABILITACION || NUMERO_SEDE AS COD_SEDE

        FROM reps_servicios
        WHERE  1 = 1
            AND HABILITADO = 'SI'
    )
    
    -- Traer la tabla de municipios
    , municipios AS (
        SELECT MPIO AS COD_MUNICIPIO
            , Municipio
            , Departamento
            , Region
            , PopTot
        FROM reps_municipios
    )
    
    -- Agrupar la tabla por servicios para tener conteos por tipo de servicio
    , servicios_oncologico AS (
        SELECT COD_MUNICIPIO, COUNT(DiSTINCT COD_SEDE) AS SEDES_ONCOLOGICO
            , 'ONCOLOGICO' AS tipo_servicio
        FROM servicios
        WHERE 1 = 1
            AND ESPECIFICIDAD_ONCOLOGICO = 'SI'
        
        GROUP BY COD_MUNICIPIO
    )
    , servicios_renal AS (
        SELECT COD_MUNICIPIO, COUNT(DiSTINCT COD_SEDE) AS SEDES_RENAL
            , 'ONCOLOGICO' AS tipo_servicio
        FROM servicios
        WHERE 1 = 1
            AND ESPECIFICIDAD_TRASPLANTE_RENAL = 'SI'
        
        GROUP BY COD_MUNICIPIO
    )

    -- Hacer la unión con la tabla de municipios para hallar la cantidad de sedes
    -- para las dos especialidades específicas por municipio
    SELECT municipios.COD_MUNICIPIO
        , municipios.Municipio
        , municipios.Departamento
        , municipios.Region
        , municipios.PopTot
        , COALESCE(SEDES_ONCOLOGICO, 0) AS SEDES_ONCOLOGICO
        , COALESCE(SEDES_RENAL, 0) AS SEDES_RENAL
    FROM municipios
    LEFT JOIN servicios_oncologico 
    ON servicios_oncologico.COD_MUNICIPIO = municipios.COD_MUNICIPIO
    
    LEFT JOIN servicios_renal 
    ON servicios_renal.COD_MUNICIPIO = municipios.COD_MUNICIPIO
    
    """
)

## Use pandas to query de reps_sedes database
df = pd.read_sql_query(query, conn)
df.to_csv('data/processed/conteos_sedes.csv', sep='|', index=False)
# Out:
#      COD_MUNICIPIO       Municipio Departamento                Region  \
# 0            05001        Medellín    Antioquia  Región Eje Cafetero
# 1            05002       Abejorral    Antioquia  Región Eje Cafetero
# 2            05004        Abriaquí    Antioquia  Región Eje Cafetero
# 3            05021      Alejandría    Antioquia  Región Eje Cafetero
# 4            05030           Amagá    Antioquia  Región Eje Cafetero
# ...            ...             ...          ...                   ...
# 1113         97889        Yavaraté       Vaupés          Región Llano
# 1114         99001  Puerto Carreño      Vichada          Región Llano
# 1115         99524    La Primavera      Vichada          Región Llano
# 1116         99624   Santa Rosalía      Vichada          Región Llano
# 1117         99773        Cumaribo      Vichada          Región Llano
#
#        PopTot  SEDES_ONCOLOGICO  SEDES_RENAL
# 0     2634570                38            3
# 1       21622                 0            0
# 2        2872                 0            0
# 3        4989                 0            0
# 4       32628                 0            0
# ...       ...               ...          ...
# 1113     1265                 0            0
# 1114    22963                 0            0
# 1115    11380                 0            0
# 1116     4732                 0            0
# 1117    88392                 0            0
#
# [1118 rows x 7 columns]
